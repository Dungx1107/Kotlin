// %%
fun main1() {
    println("Weather forecast")
    println("Sunny")
}
main1()
// Out:
// Weather forecast
// Sunny

// %% [markdown]
// Thêm độ trễ

// %%
@file:DependsOn("org.jetbrains.kotlinx:kotlinx-coroutines-core:1.7.3")

// %%
import kotlinx.coroutines.*

fun main2() = runBlocking {
    println("Weather forecast")
    delay(1000)
    println("Sunny")
}

// %%
main2()
// Out:
// Weather forecast
// Sunny

// %%
suspend fun printTemperature() {
    delay(1000)
    println("30\u00b0C")
}

// %%
runBlocking { printTemperature() }
// Out:
// 30°C
